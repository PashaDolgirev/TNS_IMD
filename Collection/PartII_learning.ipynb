# %%
using ITensors, ITensorMPS, Optim, LinearAlgebra, Printf, Random, Plots, DelimitedFiles
Random.seed!(123)
include("src/QuantumResource1D.jl")
include("src/HL_module.jl")

all_params_mat = readdlm("DATA/all_params_mat.txt") 
g_vals = vec(readdlm("DATA/g_values.txt"));

# %%
N = 5

λ_vals, Fidelities_HL = [], []
H_params, delta_E_HL = [], []
HL_X_exp, HL_O_exp, HL_ZZ_exp = [], [], []

for ind_g in 1:length(g_vals)
    println("Current value: g = $(g_vals[ind_g])")
    θ_g = all_params_mat[:, ind_g]

    qr_g = QR1D.QuantumResource1D(N)
    psi_g = QR1D.apply_ladder_circuit(qr_g, θ_g)

    hl_g = HL1D.HamiltonianLearner(psi_g)
    λ_min_g, v_min_g = HL1D.LearnHamiltonian_corr_mat(hl_g)

    push!(λ_vals, λ_min_g)
    push!(H_params, v_min_g)
    push!(delta_E_HL, hl_g.E_psi - hl_g.E_GS)
    push!(Fidelities_HL, hl_g.Fidelity)

    push!(HL_X_exp, real(inner(hl_g.ψ_GS, qr_g.aux_ops[1], hl_g.ψ_GS)))
    push!(HL_O_exp, real(inner(hl_g.ψ_GS, qr_g.aux_ops[2], hl_g.ψ_GS)))
    push!(HL_ZZ_exp, real(inner(hl_g.ψ_GS, qr_g.aux_ops[3], hl_g.ψ_GS)))
end
# Out:
# Current value: g = -1.0
# ┌ Warning: Calling `inner(x::MPS, A::MPO, y::MPS)` where the site indices of the `MPS`
# │ `x` and the `MPS` resulting from contracting `MPO` `A` with `MPS` `y` don't
# │ match is deprecated as of ITensors v0.3 and will result in an error in ITensors
# │ v0.4. The most common cause of this is something like the following:
# │
# │ ```julia
# │ s = siteinds("S=1/2")
# │ psi = random_mps(s)
# │ H = MPO(s, "Id")
# │ inner(psi, H, psi)
# │ ```
# │
# │ `psi` has the Index structure `-s-(psi)` and `H` has the Index structure
# │ `-s'-(H)-s-`, so the Index structure of would be `(dag(psi)-s- -s'-(H)-s-(psi)`
# │  unless the prime levels were fixed. Previously we tried fixing the prime level
# │   in situations like this, but we will no longer be doing that going forward.
# │
# │ There are a few ways to fix this. You can simply change:
# │
# │ ```julia
# │ inner(psi, H, psi)
# │ ```
# │
# │ to:
# │
# │ ```julia
# │ inner(psi', H, psi)
# │ ```
# │
# │ in which case the Index structure will be `(dag(psi)-s'-(H)-s-(psi)`.
# │
# │ Alternatively, you can use the `Apply` function:
# │
# │ ```julia
# │
# │ inner(psi, Apply(H, psi))
# │ ```
# │
# │ In this case, `Apply(H, psi)` represents the "lazy" evaluation of
# │ `apply(H, psi)`. The function `apply(H, psi)` performs the contraction of
# │ `H` with `psi` and then unprimes the results, so this versions ensures that
# │ the prime levels of the inner product will match.
# │
# │ Although the new behavior seems less convenient, it makes it easier to
# │ generalize `inner(::MPS, ::MPO, ::MPS)` to other types of inputs, like `MPS`
# │ and `MPO` with different tag and prime conventions, multiple sites per tensor,
# │ `ITensor` inputs, etc.
# │
# │ Stacktrace:
# │   [1] backtrace()
# │     @ Base ./error.jl:114
# │   [2] warn_once(msg::String, funcsym::Symbol; force::Bool, stacktrace::Bool)
# │     @ ITensors ~/.julia/packages/ITensors/AQFcD/src/utils.jl:8
# │   [3] warn_once
# │     @ ~/.julia/packages/ITensors/AQFcD/src/utils.jl:5 [inlined]
# │   [4] deprecate_make_inds_match!(::typeof(ITensorMPS._log_or_not_dot), M1dag::MPS, M2::MPS, loginner::Bool; make_inds_match::Bool)
# │     @ ITensorMPS ~/.julia/packages/ITensorMPS/JFTPj/src/abstractmps.jl:1092
# │   [5] deprecate_make_inds_match!
# │     @ ~/.julia/packages/ITensorMPS/JFTPj/src/abstractmps.jl:1057 [inlined]
# │   [6] _log_or_not_dot(M1::MPS, M2::MPS, loginner::Bool; make_inds_match::Bool)
# │     @ ITensorMPS ~/.julia/packages/ITensorMPS/JFTPj/src/abstractmps.jl:1107
# │   [7] _log_or_not_dot
# │     @ ~/.julia/packages/ITensorMPS/JFTPj/src/abstractmps.jl:1098 [inlined]
# │   [8] #dot#295
# │     @ ~/.julia/packages/ITensorMPS/JFTPj/src/abstractmps.jl:1158 [inlined]
# │   [9] dot
# │     @ ~/.julia/packages/ITensorMPS/JFTPj/src/abstractmps.jl:1157 [inlined]
# │  [10] inner
# │     @ ~/.julia/packages/ITensorMPS/JFTPj/src/abstractmps.jl:1200 [inlined]
# │  [11] generate_correlation_matrix(hl::Main.HL1D.HamiltonianLearner)
# │     @ Main.HL1D ~/Documents/GitProjects/TNS_MaterialDesign/src/HL1D_utils.jl:259
# │  [12] LearnHamiltonian_corr_mat(hl::Main.HL1D.HamiltonianLearner)
# │     @ Main.HL1D ~/Documents/GitProjects/TNS_MaterialDesign/src/HL1D_utils.jl:331
# │  [13] top-level scope
# │     @ ~/Documents/GitProjects/TNS_MaterialDesign/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W1sZmlsZQ==.jl:15
# │  [14] eval
# │     @ ./boot.jl:430 [inlined]
# │  [15] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
# │     @ Base ./loading.jl:2734
# │  [16] #invokelatest#2
# │     @ ./essentials.jl:1055 [inlined]
# │  [17] invokelatest
# │     @ ./essentials.jl:1052 [inlined]
# │  [18] (::VSCodeServer.var"#217#218"{VSCodeServer.NotebookRunCellArguments, String})()
# │     @ VSCodeServer ~/.vscode/extensions/julialang.language-julia-1.149.2/scripts/packages/VSCodeServer/src/serve_notebook.jl:24
# │  [19] withpath(f::VSCodeServer.var"#217#218"{VSCodeServer.NotebookRunCellArguments, String}, path::String)
# │     @ VSCodeServer ~/.vscode/extensions/julialang.language-julia-1.149.2/scripts/packages/VSCodeServer/src/repl.jl:276
# │  [20] notebook_runcell_request(conn::VSCodeServer.JSONRPC.JSONRPCEndpoint{Base.PipeEndpoint, Base.PipeEndpoint, VSCodeServer.JSON.Serializations.StandardSerialization}, params::VSCodeServer.NotebookRunCellArguments, token::VSCodeServer.CancellationTokens.CancellationToken)
# │     @ VSCodeServer ~/.vscode/extensions/julialang.language-julia-1.149.2/scripts/packages/VSCodeServer/src/serve_notebook.jl:13
# │  [21] dispatch_msg(x::VSCodeServer.JSONRPC.JSONRPCEndpoint{Base.PipeEndpoint, Base.PipeEndpoint, VSCodeServer.JSON.Serializations.StandardSerialization}, dispatcher::VSCodeServer.JSONRPC.MsgDispatcher, msg::VSCodeServer.JSONRPC.Request)
# │     @ VSCodeServer.JSONRPC ~/.vscode/extensions/julialang.language-julia-1.149.2/scripts/packages/JSONRPC/src/typed.jl:68
# │  [22] serve_notebook(pipename::String, debugger_pipename::String, outputchannel_logger::Base.CoreLogging.SimpleLogger; error_handler::var"#5#10"{String})
# │     @ VSCodeServer ~/.vscode/extensions/julialang.language-julia-1.149.2/scripts/packages/VSCodeServer/src/serve_notebook.jl:147
# │  [23] top-level scope
# │     @ ~/.vscode/extensions/julialang.language-julia-1.149.2/scripts/notebook/notebook.jl:35
# │  [24] include(mod::Module, _path::String)
# │     @ Base ./Base.jl:557
# │  [25] exec_options(opts::Base.JLOptions)
# │     @ Base ./client.jl:323
# │  [26] _start()
# │     @ Base ./client.jl:531
# │   caller = ip:0x0
# └ @ Core :-1
# Degeneracy = 8
# After sweep 1 energy=-5.179286934671322  maxlinkdim=2 maxerr=4.32E-16 time=3.232
# After sweep 2 energy=-5.179286934671319  maxlinkdim=2 maxerr=4.36E-16 time=0.010
# After sweep 3 energy=-5.179286934671318  maxlinkdim=2 maxerr=3.33E-16 time=0.001
# After sweep 4 energy=-5.179286934671321  maxlinkdim=2 maxerr=4.09E-16 time=0.001
# After sweep 5 energy=-5.179286934671325  maxlinkdim=2 maxerr=4.35E-16 time=0.001
# After sweep 6 energy=-5.1792869346713255  maxlinkdim=2 maxerr=4.79E-16 time=0.001
# After sweep 7 energy=-5.179286934671326  maxlinkdim=2 maxerr=3.06E-16 time=0.001
# After sweep 8 energy=-5.179286934671319  maxlinkdim=2 maxerr=3.83E-16 time=0.001
# Fidelity = 0.9999999999999993
# GS energy = -5.179286934671319
# Current value: g = -0.9797979797979798
# Degeneracy = 3
# ┌ Warning: Calling `inner(x::MPS, A::MPO, y::MPS)` where the site indices of the `MPS`
# │ `x` and the `MPS` resulting from contracting `MPO` `A` with `MPS` `y` don't
# │ match is deprecated as of ITensors v0.3 and will result in an error in ITensors
# │ v0.4. The most common cause of this is something like the following:
# │
# │ ```julia
# │ s = siteinds("S=1/2")
# │ psi = random_mps(s)
# │ H = MPO(s, "Id")
# │ inner(psi, H, psi)
# │ ```
# │
# │ `psi` has the Index structure `-s-(psi)` and `H` has the Index structure
# │ `-s'-(H)-s-`, so the Index structure of would be `(dag(psi)-s- -s'-(H)-s-(psi)`
# │  unless the prime levels were fixed. Previously we tried fixing the prime level
# │   in situations like this, but we will no longer be doing that going forward.
# │
# │ There are a few ways to fix this. You can simply change:
# │
# │ ```julia
# │ inner(psi, H, psi)
# │ ```
# │
# │ to:
# │
# │ ```julia
# │ inner(psi', H, psi)
# │ ```
# │
# │ in which case the Index structure will be `(dag(psi)-s'-(H)-s-(psi)`.
# │
# │ Alternatively, you can use the `Apply` function:
# │
# │ ```julia
# │
# │ inner(psi, Apply(H, psi))
# │ ```
# │
# │ In this case, `Apply(H, psi)` represents the "lazy" evaluation of
# │ `apply(H, psi)`. The function `apply(H, psi)` performs the contraction of
# │ `H` with `psi` and then unprimes the results, so this versions ensures that
# │ the prime levels of the inner product will match.
# │
# │ Although the new behavior seems less convenient, it makes it easier to
# │ generalize `inner(::MPS, ::MPO, ::MPS)` to other types of inputs, like `MPS`
# │ and `MPO` with different tag and prime conventions, multiple sites per tensor,
# │ `ITensor` inputs, etc.
# │
# │ Stacktrace:
# │   [1] warn_once(msg::String, funcsym::Symbol; force::Bool, stacktrace::Bool)
# │     @ ITensors ~/.julia/packages/ITensors/AQFcD/src/utils.jl:8
# │   [2] warn_once
# │     @ ~/.julia/packages/ITensors/AQFcD/src/utils.jl:5 [inlined]
# │   [3] deprecate_make_inds_match!(::typeof(dot), ydag::MPS, A::MPO, x::MPS; make_inds_match::Bool)
# │     @ ITensorMPS ~/.julia/packages/ITensorMPS/JFTPj/src/mpo.jl:363
# │   [4] deprecate_make_inds_match!
# │     @ ~/.julia/packages/ITensorMPS/JFTPj/src/mpo.jl:342 [inlined]
# │   [5] _log_or_not_dot(y::MPS, A::MPO, x::MPS, loginner::Bool; make_inds_match::Bool, kwargs::@Kwargs{})
# │     @ ITensorMPS ~/.julia/packages/ITensorMPS/JFTPj/src/mpo.jl:377
# │   [6] _log_or_not_dot
# │     @ ~/.julia/packages/ITensorMPS/JFTPj/src/mpo.jl:370 [inlined]
# │   [7] #dot#448
# │     @ ~/.julia/packages/ITensorMPS/JFTPj/src/mpo.jl:409 [inlined]
# │   [8] dot
# │     @ ~/.julia/packages/ITensorMPS/JFTPj/src/mpo.jl:408 [inlined]
# │   [9] inner
# │     @ ~/.julia/packages/ITensorMPS/JFTPj/src/mpo.jl:450 [inlined]
# │  [10] top-level scope
# │     @ ~/Documents/GitProjects/TNS_MaterialDesign/jl_notebook_cell_df34fa98e69747e1a8f8a730347b8e2f_W1sZmlsZQ==.jl:22
# │  [11] eval
# │     @ ./boot.jl:430 [inlined]
# │  [12] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
# │     @ Base ./loading.jl:2734
# │  [13] #invokelatest#2
# │     @ ./essentials.jl:1055 [inlined]
# │  [14] invokelatest
# │     @ ./essentials.jl:1052 [inlined]
# │  [15] (::VSCodeServer.var"#217#218"{VSCodeServer.NotebookRunCellArguments, String})()
# │     @ VSCodeServer ~/.vscode/extensions/julialang.language-julia-1.149.2/scripts/packages/VSCodeServer/src/serve_notebook.jl:24
# │  [16] withpath(f::VSCodeServer.var"#217#218"{VSCodeServer.NotebookRunCellArguments, String}, path::String)
# │     @ VSCodeServer ~/.vscode/extensions/julialang.language-julia-1.149.2/scripts/packages/VSCodeServer/src/repl.jl:276
# │  [17] notebook_runcell_request(conn::VSCodeServer.JSONRPC.JSONRPCEndpoint{Base.PipeEndpoint, Base.PipeEndpoint, VSCodeServer.JSON.Serializations.StandardSerialization}, params::VSCodeServer.NotebookRunCellArguments, token::VSCodeServer.CancellationTokens.CancellationToken)
# │     @ VSCodeServer ~/.vscode/extensions/julialang.language-julia-1.149.2/scripts/packages/VSCodeServer/src/serve_notebook.jl:13
# │  [18] dispatch_msg(x::VSCodeServer.JSONRPC.JSONRPCEndpoint{Base.PipeEndpoint, Base.PipeEndpoint, VSCodeServer.JSON.Serializations.StandardSerialization}, dispatcher::VSCodeServer.JSONRPC.MsgDispatcher, msg::VSCodeServer.JSONRPC.Request)
# │     @ VSCodeServer.JSONRPC ~/.vscode/extensions/julialang.language-julia-1.149.2/scripts/packages/JSONRPC/src/typed.jl:68
# │  [19] serve_notebook(pipename::String, debugger_pipename::String, outputchannel_logger::Base.CoreLogging.SimpleLogger; error_handler::var"#5#10"{String})
# │     @ VSCodeServer ~/.vscode/extensions/julialang.language-julia-1.149.2/scripts/packages/VSCodeServer/src/serve_notebook.jl:147
# │  [20] top-level scope
# │     @ ~/.vscode/extensions/julialang.language-julia-1.149.2/scripts/notebook/notebook.jl:35
# │  [21] include(mod::Module, _path::String)
# │     @ Base ./Base.jl:557
# │  [22] exec_options(opts::Base.JLOptions)
# │     @ Base ./client.jl:323
# │  [23] _start()
# │     @ Base ./client.jl:531
# │   caller = ip:0x0
# └ @ Core :-1
# After sweep 1 energy=-1.4532322445149437  maxlinkdim=2 maxerr=7.58E-14 time=0.013
# After sweep 2 energy=-1.453232244514943  maxlinkdim=2 maxerr=3.22E-14 time=0.002
# After sweep 3 energy=-1.4532322445149435  maxlinkdim=2 maxerr=3.20E-14 time=0.001
# After sweep 4 energy=-1.4532322445149433  maxlinkdim=2 maxerr=3.22E-14 time=0.001
# After sweep 5 energy=-1.4532322445149433  maxlinkdim=2 maxerr=3.20E-14 time=0.001
# After sweep 6 energy=-1.453232244514943  maxlinkdim=2 maxerr=3.22E-14 time=0.001
# After sweep 7 energy=-1.4532322445149437  maxlinkdim=2 maxerr=3.22E-14 time=0.001
# After sweep 8 energy=-1.4532322445149426  maxlinkdim=2 maxerr=3.20E-14 time=0.001
# Fidelity = 9.295183132642807e-12
# GS energy = -1.4532322445149426
# Current value: g = -0.9595959595959596
# Degeneracy = 2
# After sweep 1 energy=-1.4122177891039414  maxlinkdim=2 maxerr=8.67E-14 time=0.002
# After sweep 2 energy=-1.4122177891049925  maxlinkdim=2 maxerr=8.95E-16 time=0.002
# After sweep 3 energy=-1.4122177891049936  maxlinkdim=2 maxerr=2.22E-16 time=0.001
# After sweep 4 energy=-1.4122177891049945  maxlinkdim=2 maxerr=1.11E-16 time=0.001
# After sweep 5 energy=-1.4122177891049936  maxlinkdim=2 maxerr=2.80E-16 time=0.001
# After sweep 6 energy=-1.4122177891049938  maxlinkdim=2 maxerr=3.46E-16 time=0.001
# After sweep 7 energy=-1.4122177891049952  maxlinkdim=2 maxerr=2.79E-16 time=0.001
# After sweep 8 energy=-1.4122177891049956  maxlinkdim=2 maxerr=2.22E-16 time=0.001
# Fidelity = 1.5092546326920307e-10
# GS energy = -1.4122177891049956
# Current value: g = -0.9393939393939394
# Degeneracy = 2
# After sweep 1 energy=-1.4124262703285184  maxlinkdim=2 maxerr=3.52E-11 time=0.002
# After sweep 2 energy=-1.412426272565122  maxlinkdim=2 maxerr=1.11E-15 time=0.005
# After sweep 3 energy=-1.412426274752445  maxlinkdim=2 maxerr=9.99E-16 time=0.001
# After sweep 4 energy=-1.412426276873229  maxlinkdim=2 maxerr=1.11E-15 time=0.001
# After sweep 5 energy=-1.4124262789127955  maxlinkdim=2 maxerr=1.11E-15 time=0.001
# After sweep 6 energy=-1.4124262808593333  maxlinkdim=2 maxerr=1.22E-15 time=0.001
# After sweep 7 energy=-1.412426282703997  maxlinkdim=2 maxerr=1.22E-15 time=0.001
# After sweep 8 energy=-1.4124262844408393  maxlinkdim=2 maxerr=1.22E-15 time=0.001
# Fidelity = 0.41946458170726636
# GS energy = -1.4124262844408393
# Current value: g = -0.9191919191919192
# Degeneracy = 2
# After sweep 1 energy=-1.4126275053389563  maxlinkdim=2 maxerr=5.51E-13 time=0.002
# After sweep 2 energy=-1.4126275053438344  maxlinkdim=2 maxerr=4.44E-16 time=0.001
# After sweep 3 energy=-1.4126275053487047  maxlinkdim=2 maxerr=4.22E-16 time=0.001
# After sweep 4 energy=-1.4126275053535666  maxlinkdim=2 maxerr=4.10E-16 time=0.001
# After sweep 5 energy=-1.4126275053584207  maxlinkdim=2 maxerr=3.46E-16 time=0.001
# After sweep 6 energy=-1.412627505363267  maxlinkdim=2 maxerr=3.90E-16 time=0.001
# After sweep 7 energy=-1.4126275053681028  maxlinkdim=2 maxerr=6.75E-16 time=0.001
# After sweep 8 energy=-1.4126275053729334  maxlinkdim=2 maxerr=2.59E-16 time=0.001
# Fidelity = 0.1302137676067242
# GS energy = -1.4126275053729334
# Current value: g = -0.898989898989899
# Degeneracy = 2
# After sweep 1 energy=-1.4128201920961347  maxlinkdim=2 maxerr=9.79E-16 time=0.002
# After sweep 2 energy=-1.4128201964053437  maxlinkdim=3 maxerr=1.32E-13 time=0.001
# After sweep 3 energy=-1.4128201994820697  maxlinkdim=2 maxerr=7.22E-13 time=0.001
# After sweep 4 energy=-1.4128201995324994  maxlinkdim=2 maxerr=9.99E-16 time=0.001
# After sweep 5 energy=-1.4128201995363387  maxlinkdim=2 maxerr=7.77E-16 time=0.001
# After sweep 6 energy=-1.4128201995367602  maxlinkdim=2 maxerr=9.00E-16 time=0.001
# After sweep 7 energy=-1.4128201995368315  maxlinkdim=2 maxerr=9.99E-16 time=0.001
# After sweep 8 energy=-1.4128201995368477  maxlinkdim=2 maxerr=7.77E-16 time=0.001
# Fidelity = 3.1245838843785163e-6
# GS energy = -1.4128201995368477
# Current value: g = -0.8787878787878788
# Degeneracy = 2
# After sweep 1 energy=-1.4130035855324512  maxlinkdim=2 maxerr=4.44E-16 time=0.002
# After sweep 2 energy=-1.4130035855324625  maxlinkdim=2 maxerr=6.52E-16 time=0.001
# After sweep 3 energy=-1.413003585532477  maxlinkdim=2 maxerr=5.12E-16 time=0.001
# After sweep 4 energy=-1.4130035855324987  maxlinkdim=2 maxerr=1.28E-15 time=0.001
# After sweep 5 energy=-1.4130035855325962  maxlinkdim=2 maxerr=6.95E-16 time=0.001
# After sweep 6 energy=-1.4130035896507083  maxlinkdim=3 maxerr=4.22E-15 time=0.001
# After sweep 7 energy=-1.413003589651421  maxlinkdim=2 maxerr=8.88E-16 time=0.001
# After sweep 8 energy=-1.4130035896514348  maxlinkdim=2 maxerr=9.99E-16 time=0.001
# Fidelity = 7.4396550484069295e-6
# GS energy = -1.4130035896514348
# Current value: g = -0.8585858585858586
# Degeneracy = 2
# After sweep 1 energy=-1.4131767437659832  maxlinkdim=2 maxerr=1.54E-14 time=0.002
# After sweep 2 energy=-1.4131767461842268  maxlinkdim=2 maxerr=1.06E-12 time=0.001
# After sweep 3 energy=-1.4131767467078236  maxlinkdim=2 maxerr=4.21E-13 time=0.001
# After sweep 4 energy=-1.4131767468371603  maxlinkdim=2 maxerr=1.35E-13 time=0.001
# After sweep 5 energy=-1.4131767468796972  maxlinkdim=2 maxerr=5.43E-14 time=0.001
# After sweep 6 energy=-1.4131767468947263  maxlinkdim=2 maxerr=2.94E-14 time=0.004
# After sweep 7 energy=-1.413176746900196  maxlinkdim=2 maxerr=1.94E-14 time=0.002
# After sweep 8 energy=-1.4131767469022487  maxlinkdim=2 maxerr=1.38E-14 time=0.001
# Fidelity = 6.171871506473214e-5
# GS energy = -1.4131767469022487
# Current value: g = -0.8383838383838383
# Degeneracy = 2
# After sweep 1 energy=-1.4133388136013447  maxlinkdim=2 maxerr=3.70E-16 time=0.002
# After sweep 2 energy=-1.4133388136013454  maxlinkdim=2 maxerr=3.85E-16 time=0.002
# After sweep 3 energy=-1.413338813601358  maxlinkdim=2 maxerr=3.88E-16 time=0.005
# After sweep 4 energy=-1.4133388136014164  maxlinkdim=2 maxerr=3.32E-16 time=0.001
# After sweep 5 energy=-1.4133388136017624  maxlinkdim=2 maxerr=5.87E-16 time=0.001
# After sweep 6 energy=-1.413338814383222  maxlinkdim=2 maxerr=2.79E-13 time=0.001
# After sweep 7 energy=-1.4133388143832455  maxlinkdim=2 maxerr=6.66E-16 time=0.001
# After sweep 8 energy=-1.4133388143832462  maxlinkdim=2 maxerr=4.50E-11 time=0.001
# Fidelity = 5.368306365542431e-6
# GS energy = -1.4133388143832462
# Current value: g = -0.8181818181818182
# Degeneracy = 2
# After sweep 1 energy=-1.413488993296624  maxlinkdim=2 maxerr=1.07E-15 time=0.002
# After sweep 2 energy=-1.4134889932966246  maxlinkdim=2 maxerr=4.66E-16 time=0.005
# After sweep 3 energy=-1.4134889932966301  maxlinkdim=2 maxerr=4.08E-16 time=0.001
# After sweep 4 energy=-1.4134889932966488  maxlinkdim=2 maxerr=2.93E-16 time=0.001
# After sweep 5 energy=-1.4134889932967285  maxlinkdim=2 maxerr=3.84E-16 time=0.001
# After sweep 6 energy=-1.4134889932970693  maxlinkdim=2 maxerr=5.38E-16 time=0.002
# After sweep 7 energy=-1.4134889940639876  maxlinkdim=2 maxerr=3.91E-13 time=0.001
# After sweep 8 energy=-1.4134889940640112  maxlinkdim=2 maxerr=9.99E-16 time=0.001
# Fidelity = 1.250515303801044e-6
# GS energy = -1.4134889940640112
# Current value: g = -0.797979797979798
# Degeneracy = 2
# After sweep 1 energy=-1.4136265359616762  maxlinkdim=2 maxerr=4.03E-16 time=0.002
# After sweep 2 energy=-1.4136265359616758  maxlinkdim=2 maxerr=1.10E-15 time=0.001
# After sweep 3 energy=-1.4136265359616775  maxlinkdim=2 maxerr=5.43E-16 time=0.005
# After sweep 4 energy=-1.4136265359616789  maxlinkdim=2 maxerr=3.76E-16 time=0.001
# After sweep 5 energy=-1.4136265359616846  maxlinkdim=2 maxerr=3.15E-16 time=0.001
# After sweep 6 energy=-1.4136265359616957  maxlinkdim=2 maxerr=5.07E-16 time=0.001
# After sweep 7 energy=-1.4136265359617217  maxlinkdim=2 maxerr=2.98E-16 time=0.001
# After sweep 8 energy=-1.4136265359617806  maxlinkdim=2 maxerr=4.07E-16 time=0.001
# Fidelity = 0.9997649552674073
# GS energy = -1.4136265359617806
# Current value: g = -0.7777777777777778
# Degeneracy = 2
# After sweep 1 energy=-1.413750768527213  maxlinkdim=2 maxerr=7.77E-16 time=0.002
# After sweep 2 energy=-1.4137507685272137  maxlinkdim=2 maxerr=8.88E-16 time=0.001
# After sweep 3 energy=-1.413750768527214  maxlinkdim=2 maxerr=1.03E-15 time=0.001
# After sweep 4 energy=-1.4137507685272148  maxlinkdim=2 maxerr=4.41E-16 time=0.001
# After sweep 5 energy=-1.4137507685272133  maxlinkdim=2 maxerr=4.62E-16 time=0.001
# After sweep 6 energy=-1.4137507685272142  maxlinkdim=2 maxerr=4.44E-16 time=0.005
# After sweep 7 energy=-1.4137507685272137  maxlinkdim=2 maxerr=3.99E-16 time=0.001
# After sweep 8 energy=-1.4137507685272142  maxlinkdim=2 maxerr=1.22E-15 time=0.001
# Fidelity = 0.9999999959152568
# GS energy = -1.4137507685272142
# Current value: g = -0.7575757575757576
# Degeneracy = 2
# After sweep 1 energy=-1.4138610881192946  maxlinkdim=2 maxerr=4.07E-16 time=0.002
# After sweep 2 energy=-1.413861088119319  maxlinkdim=2 maxerr=1.12E-15 time=0.001
# After sweep 3 energy=-1.4138610881194231  maxlinkdim=2 maxerr=3.54E-16 time=0.001
# After sweep 4 energy=-1.4138610885512666  maxlinkdim=2 maxerr=6.45E-14 time=0.001
# After sweep 5 energy=-1.4138610885512948  maxlinkdim=2 maxerr=9.99E-16 time=0.001
# After sweep 6 energy=-1.4138610885512963  maxlinkdim=2 maxerr=1.19E-15 time=0.001
# After sweep 7 energy=-1.413861088551296  maxlinkdim=2 maxerr=9.44E-16 time=0.001
# After sweep 8 energy=-1.4138610885512959  maxlinkdim=2 maxerr=2.60E-16 time=0.001
# Fidelity = 2.3916342591722423e-5
# GS energy = -1.4138610885512959
# Current value: g = -0.7373737373737373
# Degeneracy = 2
# After sweep 1 energy=-1.413956980402206  maxlinkdim=2 maxerr=4.44E-16 time=0.002
# After sweep 2 energy=-1.413956980402206  maxlinkdim=2 maxerr=9.99E-16 time=0.005
# After sweep 3 energy=-1.4139569804022083  maxlinkdim=2 maxerr=4.44E-16 time=0.002
# After sweep 4 energy=-1.4139569804022065  maxlinkdim=2 maxerr=4.34E-16 time=0.001
# After sweep 5 energy=-1.413956980402208  maxlinkdim=2 maxerr=4.83E-16 time=0.001
# After sweep 6 energy=-1.413956980402208  maxlinkdim=2 maxerr=4.37E-16 time=0.002
# After sweep 7 energy=-1.4139569804022072  maxlinkdim=2 maxerr=4.30E-16 time=0.001
# After sweep 8 energy=-1.4139569804022076  maxlinkdim=2 maxerr=8.88E-16 time=0.001
# Fidelity = 0.9999999932231536
# GS energy = -1.4139569804022076
# Current value: g = -0.7171717171717171
# Degeneracy = 2
# After sweep 1 energy=-1.4140380274366156  maxlinkdim=2 maxerr=1.01E-15 time=0.002
# After sweep 2 energy=-1.4140380274366162  maxlinkdim=2 maxerr=4.03E-16 time=0.001
# After sweep 3 energy=-1.4140380274366229  maxlinkdim=2 maxerr=8.88E-16 time=0.001
# After sweep 4 energy=-1.4140380274366458  maxlinkdim=2 maxerr=9.63E-16 time=0.001
# After sweep 5 energy=-1.4140380274367235  maxlinkdim=2 maxerr=7.77E-16 time=0.001
# After sweep 6 energy=-1.4140380274370286  maxlinkdim=2 maxerr=7.43E-16 time=0.001
# After sweep 7 energy=-1.4140380277327187  maxlinkdim=2 maxerr=1.83E-13 time=0.001
# After sweep 8 energy=-1.4140380277327338  maxlinkdim=2 maxerr=7.98E-16 time=0.001
# Fidelity = 3.006200443577778e-6
# GS energy = -1.4140380277327338
# Current value: g = -0.696969696969697
# Degeneracy = 2
# After sweep 1 energy=-1.4141039084187998  maxlinkdim=2 maxerr=6.38E-16 time=0.002
# After sweep 2 energy=-1.4141039084187998  maxlinkdim=2 maxerr=3.69E-16 time=0.002
# After sweep 3 energy=-1.4141039084188003  maxlinkdim=2 maxerr=4.04E-16 time=0.001
# After sweep 4 energy=-1.4141039084187998  maxlinkdim=2 maxerr=3.37E-16 time=0.001
# After sweep 5 energy=-1.4141039084188005  maxlinkdim=2 maxerr=7.84E-16 time=0.005
# After sweep 6 energy=-1.4141039084188007  maxlinkdim=2 maxerr=7.77E-16 time=0.002
# After sweep 7 energy=-1.4141039084188003  maxlinkdim=2 maxerr=7.82E-16 time=0.001
# After sweep 8 energy=-1.4141039084187996  maxlinkdim=2 maxerr=8.88E-16 time=0.001
# Fidelity = 0.9999999999443292
# GS energy = -1.4141039084187996
# Current value: g = -0.6767676767676768
# Degeneracy = 2
# After sweep 1 energy=-1.4141544098335208  maxlinkdim=2 maxerr=4.58E-16 time=0.002
# After sweep 2 energy=-1.4141544098335204  maxlinkdim=2 maxerr=3.32E-16 time=0.005
# After sweep 3 energy=-1.4141544098335208  maxlinkdim=2 maxerr=4.78E-16 time=0.001
# After sweep 4 energy=-1.4141544098335206  maxlinkdim=2 maxerr=3.91E-16 time=0.001
# After sweep 5 energy=-1.4141544098335208  maxlinkdim=2 maxerr=8.94E-16 time=0.001
# After sweep 6 energy=-1.4141544098335215  maxlinkdim=2 maxerr=8.12E-16 time=0.002
# After sweep 7 energy=-1.4141544098335208  maxlinkdim=2 maxerr=5.27E-16 time=0.001
# After sweep 8 energy=-1.414154409833521  maxlinkdim=2 maxerr=6.66E-16 time=0.001
# Fidelity = 0.9999962879975686
# GS energy = -1.414154409833521
# Current value: g = -0.6565656565656566
# Degeneracy = 2
# After sweep 1 energy=-1.4141894282829117  maxlinkdim=2 maxerr=6.10E-16 time=0.002
# After sweep 2 energy=-1.41418942828291  maxlinkdim=2 maxerr=8.88E-16 time=0.002
# After sweep 3 energy=-1.4141894282829106  maxlinkdim=2 maxerr=9.99E-16 time=0.001
# After sweep 4 energy=-1.414189428282911  maxlinkdim=2 maxerr=8.88E-16 time=0.001
# After sweep 5 energy=-1.4141894282829106  maxlinkdim=2 maxerr=9.42E-16 time=0.001
# After sweep 6 energy=-1.4141894282829108  maxlinkdim=2 maxerr=8.91E-16 time=0.001
# After sweep 7 energy=-1.4141894282829108  maxlinkdim=2 maxerr=3.81E-16 time=0.001
# After sweep 8 energy=-1.4141894282829115  maxlinkdim=2 maxerr=3.74E-16 time=0.002
# Fidelity = 0.9999999999314348
# GS energy = -1.4141894282829115
# Current value: g = -0.6363636363636364
# Degeneracy = 2
# After sweep 1 energy=-1.414208975807721  maxlinkdim=2 maxerr=9.99E-16 time=0.002
# After sweep 2 energy=-1.4142089758077268  maxlinkdim=2 maxerr=1.02E-15 time=0.002
# After sweep 3 energy=-1.4142089758077343  maxlinkdim=2 maxerr=9.99E-16 time=0.001
# After sweep 4 energy=-1.4142089758077463  maxlinkdim=2 maxerr=1.00E-15 time=0.002
# After sweep 5 energy=-1.4142089758484366  maxlinkdim=2 maxerr=6.70E-15 time=0.001
# After sweep 6 energy=-1.4142089758486245  maxlinkdim=2 maxerr=2.94E-15 time=0.001
# After sweep 7 energy=-1.4142089758487015  maxlinkdim=2 maxerr=1.80E-15 time=0.001
# After sweep 8 energy=-1.4142089758487388  maxlinkdim=2 maxerr=1.12E-15 time=0.001
# Fidelity = 1.950185042122269e-6
# GS energy = -1.4142089758487388
# Current value: g = -0.6161616161616161
# Degeneracy = 2
# After sweep 1 energy=-1.41421318233088  maxlinkdim=2 maxerr=8.88E-16 time=0.002
# After sweep 2 energy=-1.4142131823308848  maxlinkdim=2 maxerr=4.74E-16 time=0.001
# After sweep 3 energy=-1.4142131823309019  maxlinkdim=2 maxerr=8.94E-16 time=0.001
# After sweep 4 energy=-1.414213182346613  maxlinkdim=2 maxerr=9.40E-15 time=0.001
# After sweep 5 energy=-1.4142131823466613  maxlinkdim=2 maxerr=1.15E-15 time=0.001
# After sweep 6 energy=-1.414213182346663  maxlinkdim=2 maxerr=1.11E-15 time=0.001
# After sweep 7 energy=-1.4142131823466633  maxlinkdim=2 maxerr=9.99E-16 time=0.001
# After sweep 8 energy=-1.4142131823466735  maxlinkdim=2 maxerr=8.88E-16 time=0.001
# Fidelity = 3.3742780678433913e-6
# GS energy = -1.4142131823466735
# Current value: g = -0.5959595959595959
# Degeneracy = 2
# After sweep 1 energy=-1.4142022989313747  maxlinkdim=2 maxerr=9.20E-16 time=0.002
# After sweep 2 energy=-1.414202298931375  maxlinkdim=2 maxerr=5.53E-16 time=0.002
# After sweep 3 energy=-1.4142022989313758  maxlinkdim=2 maxerr=9.09E-16 time=0.001
# After sweep 4 energy=-1.414202298931374  maxlinkdim=2 maxerr=1.00E-15 time=0.001
# After sweep 5 energy=-1.414202298931374  maxlinkdim=2 maxerr=7.82E-16 time=0.001
# After sweep 6 energy=-1.4142022989313743  maxlinkdim=2 maxerr=7.77E-16 time=0.001
# After sweep 7 energy=-1.4142022989313738  maxlinkdim=2 maxerr=9.99E-16 time=0.001
# After sweep 8 energy=-1.4142022989313743  maxlinkdim=2 maxerr=8.95E-16 time=0.001
# Fidelity = 0.9999999842888881
# GS energy = -1.4142022989313743
# Current value: g = -0.5757575757575758
# Degeneracy = 2
# After sweep 1 energy=-1.4141766998843466  maxlinkdim=2 maxerr=8.88E-16 time=0.002
# After sweep 2 energy=-1.4141766998843455  maxlinkdim=2 maxerr=9.99E-16 time=0.001
# After sweep 3 energy=-1.414176699884347  maxlinkdim=2 maxerr=8.05E-16 time=0.001
# After sweep 4 energy=-1.4141766998843452  maxlinkdim=2 maxerr=4.53E-16 time=0.001
# After sweep 5 energy=-1.4141766998843468  maxlinkdim=2 maxerr=4.69E-16 time=0.001
# After sweep 6 energy=-1.414176699884347  maxlinkdim=2 maxerr=9.99E-16 time=0.001
# After sweep 7 energy=-1.4141766998843472  maxlinkdim=2 maxerr=7.81E-16 time=0.001
# After sweep 8 energy=-1.4141766998843472  maxlinkdim=2 maxerr=7.77E-16 time=0.001
# Fidelity = 0.9998936662825519
# GS energy = -1.4141766998843472
# Current value: g = -0.5555555555555556
# Degeneracy = 2
# After sweep 1 energy=-1.4141368831411851  maxlinkdim=2 maxerr=1.00E-15 time=0.002
# After sweep 2 energy=-1.4141368831411854  maxlinkdim=2 maxerr=1.00E-15 time=0.001
# After sweep 3 energy=-1.4141368831411831  maxlinkdim=2 maxerr=8.88E-16 time=0.001
# After sweep 4 energy=-1.414136883141184  maxlinkdim=2 maxerr=7.23E-16 time=0.001
# After sweep 5 energy=-1.4141368831411856  maxlinkdim=2 maxerr=5.48E-16 time=0.005
# After sweep 6 energy=-1.414136883141184  maxlinkdim=2 maxerr=8.99E-16 time=0.002
# After sweep 7 energy=-1.414136883141186  maxlinkdim=2 maxerr=8.88E-16 time=0.001
# After sweep 8 energy=-1.4141368831411838  maxlinkdim=2 maxerr=7.77E-16 time=0.001
# Fidelity = 0.9999999999998097
# GS energy = -1.4141368831411838
# Current value: g = -0.5353535353535354
# Degeneracy = 2
# After sweep 1 energy=-1.414083472788104  maxlinkdim=2 maxerr=8.88E-16 time=0.002
# After sweep 2 energy=-1.4140834727881038  maxlinkdim=2 maxerr=8.88E-16 time=0.001
# After sweep 3 energy=-1.4140834727881038  maxlinkdim=2 maxerr=7.77E-16 time=0.001
# After sweep 4 energy=-1.4140834727881044  maxlinkdim=2 maxerr=1.02E-15 time=0.001
# After sweep 5 energy=-1.4140834727881042  maxlinkdim=2 maxerr=8.88E-16 time=0.001
# After sweep 6 energy=-1.4140834727881033  maxlinkdim=2 maxerr=1.11E-15 time=0.001
# After sweep 7 energy=-1.414083472788105  maxlinkdim=2 maxerr=7.77E-16 time=0.001
# After sweep 8 energy=-1.4140834727881038  maxlinkdim=2 maxerr=8.03E-16 time=0.001
# Fidelity = 0.9999999999745979
# GS energy = -1.4140834727881038
# Current value: g = -0.5151515151515151
# Degeneracy = 2
# After sweep 1 energy=-1.4140172194259408  maxlinkdim=2 maxerr=4.15E-16 time=0.002
# After sweep 2 energy=-1.4140172194259417  maxlinkdim=2 maxerr=8.88E-16 time=0.001
# After sweep 3 energy=-1.4140172194259422  maxlinkdim=2 maxerr=8.88E-16 time=0.001
# After sweep 4 energy=-1.4140172194259417  maxlinkdim=2 maxerr=7.77E-16 time=0.001
# After sweep 5 energy=-1.414017219425942  maxlinkdim=2 maxerr=1.11E-15 time=0.001
# After sweep 6 energy=-1.414017219425942  maxlinkdim=2 maxerr=8.88E-16 time=0.001
# After sweep 7 energy=-1.41401721942594  maxlinkdim=2 maxerr=4.09E-16 time=0.001
# After sweep 8 energy=-1.4140172194259415  maxlinkdim=2 maxerr=8.88E-16 time=0.001
# Fidelity = 0.9999999992536224
# GS energy = -1.4140172194259415
# Current value: g = -0.494949494949495
# Degeneracy = 2
# After sweep 1 energy=-1.4139390015795243  maxlinkdim=2 maxerr=1.04E-15 time=0.002
# After sweep 2 energy=-1.4139390015795266  maxlinkdim=2 maxerr=8.88E-16 time=0.002
# After sweep 3 energy=-1.4139390015795243  maxlinkdim=2 maxerr=4.03E-16 time=0.001
# After sweep 4 energy=-1.4139390015795248  maxlinkdim=2 maxerr=6.66E-16 time=0.001
# After sweep 5 energy=-1.4139390015795228  maxlinkdim=2 maxerr=7.97E-16 time=0.001
# After sweep 6 energy=-1.4139390015795252  maxlinkdim=2 maxerr=8.89E-16 time=0.001
# After sweep 7 energy=-1.4139390015795226  maxlinkdim=2 maxerr=8.89E-16 time=0.005
# After sweep 8 energy=-1.4139390015795235  maxlinkdim=2 maxerr=9.16E-16 time=0.001
# Fidelity = 0.9999999996644144
# GS energy = -1.4139390015795235
# Current value: g = -0.47474747474747475
# Degeneracy = 2
# After sweep 1 energy=-1.4138498258262422  maxlinkdim=2 maxerr=8.88E-16 time=0.002
# After sweep 2 energy=-1.4138498258262424  maxlinkdim=2 maxerr=1.11E-15 time=0.001
# After sweep 3 energy=-1.413849825826242  maxlinkdim=2 maxerr=8.88E-16 time=0.001
# After sweep 4 energy=-1.4138498258262422  maxlinkdim=2 maxerr=8.88E-16 time=0.001
# After sweep 5 energy=-1.4138498258262426  maxlinkdim=2 maxerr=8.88E-16 time=0.001
# After sweep 6 energy=-1.4138498258262429  maxlinkdim=2 maxerr=6.66E-16 time=0.001
# After sweep 7 energy=-1.4138498258262424  maxlinkdim=2 maxerr=7.87E-16 time=0.001
# After sweep 8 energy=-1.4138498258262415  maxlinkdim=2 maxerr=4.31E-16 time=0.001
# Fidelity = 0.9999999999994267
# GS energy = -1.4138498258262415
# Current value: g = -0.45454545454545453
# Degeneracy = 2
# After sweep 1 energy=-1.4137508276455486  maxlinkdim=2 maxerr=1.00E-15 time=0.002
# After sweep 2 energy=-1.4137508276455488  maxlinkdim=2 maxerr=6.87E-16 time=0.002
# After sweep 3 energy=-1.4137508276455495  maxlinkdim=2 maxerr=9.84E-16 time=0.001
# After sweep 4 energy=-1.4137508276455497  maxlinkdim=2 maxerr=8.88E-16 time=0.001
# After sweep 5 energy=-1.4137508276455482  maxlinkdim=2 maxerr=8.88E-16 time=0.001
# After sweep 6 energy=-1.4137508276455477  maxlinkdim=2 maxerr=5.11E-16 time=0.001
# After sweep 7 energy=-1.4137508276455497  maxlinkdim=2 maxerr=9.19E-16 time=0.005
# After sweep 8 energy=-1.4137508276455488  maxlinkdim=2 maxerr=9.27E-16 time=0.001
# Fidelity = 0.9999999999999913
# GS energy = -1.4137508276455488
# Current value: g = -0.43434343434343436
# Degeneracy = 2
# After sweep 1 energy=-1.413643274785694  maxlinkdim=2 maxerr=9.42E-16 time=0.002
# After sweep 2 energy=-1.4136432747856933  maxlinkdim=2 maxerr=1.04E-15 time=0.001
# After sweep 3 energy=-1.4136432747856942  maxlinkdim=2 maxerr=5.09E-16 time=0.001
# After sweep 4 energy=-1.4136432747856953  maxlinkdim=2 maxerr=6.66E-16 time=0.001
# After sweep 5 energy=-1.4136432747856953  maxlinkdim=2 maxerr=6.12E-16 time=0.001
# After sweep 6 energy=-1.4136432747856946  maxlinkdim=2 maxerr=9.16E-16 time=0.001
# After sweep 7 energy=-1.4136432747856944  maxlinkdim=2 maxerr=8.88E-16 time=0.001
# After sweep 8 energy=-1.4136432747856953  maxlinkdim=2 maxerr=8.89E-16 time=0.001
# Fidelity = 0.9999999999999927
# GS energy = -1.4136432747856953
# Current value: g = -0.41414141414141414
# Degeneracy = 2
# After sweep 1 energy=-1.4135285664715247  maxlinkdim=2 maxerr=9.11E-16 time=0.002
# After sweep 2 energy=-1.4135285664715243  maxlinkdim=2 maxerr=9.99E-16 time=0.002
# After sweep 3 energy=-1.4135285664715231  maxlinkdim=2 maxerr=9.15E-16 time=0.001
# After sweep 4 energy=-1.4135285664715256  maxlinkdim=2 maxerr=4.64E-16 time=0.001
# After sweep 5 energy=-1.4135285664715238  maxlinkdim=2 maxerr=9.50E-16 time=0.001
# After sweep 6 energy=-1.4135285664715256  maxlinkdim=2 maxerr=8.88E-16 time=0.001
# After sweep 7 energy=-1.413528566471523  maxlinkdim=2 maxerr=1.11E-15 time=0.001
# After sweep 8 energy=-1.4135285664715247  maxlinkdim=2 maxerr=1.05E-15 time=0.005
# Fidelity = 0.9999999999999984
# GS energy = -1.4135285664715247
# Current value: g = -0.3939393939393939
# Degeneracy = 2
# After sweep 1 energy=-1.4134082373755357  maxlinkdim=2 maxerr=8.88E-16 time=0.001
# After sweep 2 energy=-1.4134082373755352  maxlinkdim=2 maxerr=9.19E-16 time=0.001
# After sweep 3 energy=-1.4134082373755357  maxlinkdim=2 maxerr=9.99E-16 time=0.001
# After sweep 4 energy=-1.4134082373755352  maxlinkdim=2 maxerr=8.88E-16 time=0.001
# After sweep 5 energy=-1.4134082373755357  maxlinkdim=2 maxerr=9.43E-16 time=0.001
# After sweep 6 energy=-1.4134082373755354  maxlinkdim=2 maxerr=7.77E-16 time=0.001
# After sweep 7 energy=-1.4134082373755354  maxlinkdim=2 maxerr=7.77E-16 time=0.001
# After sweep 8 energy=-1.413408237375535  maxlinkdim=2 maxerr=7.77E-16 time=0.001
# Fidelity = 0.9999999999999998
# GS energy = -1.413408237375535
# Current value: g = -0.37373737373737376
# Degeneracy = 2
# After sweep 1 energy=-1.413283961797184  maxlinkdim=2 maxerr=1.01E-15 time=0.002
# After sweep 2 energy=-1.4132839617971826  maxlinkdim=2 maxerr=1.05E-15 time=0.002
# After sweep 3 energy=-1.413283961797182  maxlinkdim=2 maxerr=8.88E-16 time=0.001
# After sweep 4 energy=-1.4132839617971833  maxlinkdim=2 maxerr=8.88E-16 time=0.001
# After sweep 5 energy=-1.4132839617971822  maxlinkdim=2 maxerr=6.66E-16 time=0.001
# After sweep 6 energy=-1.4132839617971829  maxlinkdim=2 maxerr=9.99E-16 time=0.001
# After sweep 7 energy=-1.4132839617971815  maxlinkdim=2 maxerr=9.99E-16 time=0.001
# After sweep 8 energy=-1.4132839617971815  maxlinkdim=2 maxerr=8.34E-16 time=0.001
# Fidelity = 0.9999999999993869
# GS energy = -1.4132839617971815
# Current value: g = -0.35353535353535354
# Degeneracy = 2
# After sweep 1 energy=-1.4131575534598142  maxlinkdim=2 maxerr=8.11E-16 time=0.002
# After sweep 2 energy=-1.4131575534598144  maxlinkdim=2 maxerr=1.11E-15 time=0.001
# After sweep 3 energy=-1.413157553459815  maxlinkdim=2 maxerr=1.00E-15 time=0.001
# After sweep 4 energy=-1.4131575534598146  maxlinkdim=2 maxerr=8.88E-16 time=0.001
# After sweep 5 energy=-1.4131575534598142  maxlinkdim=2 maxerr=7.78E-16 time=0.001
# After sweep 6 energy=-1.4131575534598155  maxlinkdim=2 maxerr=9.99E-16 time=0.001
# After sweep 7 energy=-1.4131575534598135  maxlinkdim=2 maxerr=1.11E-15 time=0.006
# After sweep 8 energy=-1.4131575534598146  maxlinkdim=2 maxerr=7.77E-16 time=0.001
# Fidelity = 0.9999999999999991
# GS energy = -1.4131575534598146
# Current value: g = -0.3333333333333333
# Degeneracy = 2
# After sweep 1 energy=-1.4130309769614045  maxlinkdim=2 maxerr=9.05E-16 time=0.002
# After sweep 2 energy=-1.4130309769614071  maxlinkdim=2 maxerr=9.43E-16 time=0.001
# After sweep 3 energy=-1.413030976961405  maxlinkdim=2 maxerr=8.88E-16 time=0.001
# After sweep 4 energy=-1.4130309769614058  maxlinkdim=2 maxerr=9.99E-16 time=0.001
# After sweep 5 energy=-1.4130309769614051  maxlinkdim=2 maxerr=5.48E-16 time=0.001
# After sweep 6 energy=-1.413030976961407  maxlinkdim=2 maxerr=8.88E-16 time=0.001
# After sweep 7 energy=-1.413030976961407  maxlinkdim=2 maxerr=9.99E-16 time=0.001
# After sweep 8 energy=-1.413030976961405  maxlinkdim=2 maxerr=1.00E-15 time=0.001
# Fidelity = 0.999999999989917
# GS energy = -1.413030976961405
# Current value: g = -0.31313131313131315
# Degeneracy = 2
# After sweep 1 energy=-1.4127809449581266  maxlinkdim=2 maxerr=1.00E-15 time=0.002
# After sweep 2 energy=-1.4127809449581248  maxlinkdim=2 maxerr=7.77E-16 time=0.002
# After sweep 3 energy=-1.412780944958125  maxlinkdim=2 maxerr=1.03E-15 time=0.001
# After sweep 4 energy=-1.4127809449581266  maxlinkdim=2 maxerr=9.99E-16 time=0.001
# After sweep 5 energy=-1.4127809449581268  maxlinkdim=2 maxerr=1.03E-15 time=0.001
# After sweep 6 energy=-1.4127809449581255  maxlinkdim=2 maxerr=5.16E-16 time=0.001
# After sweep 7 energy=-1.4127809449581263  maxlinkdim=2 maxerr=1.11E-15 time=0.001
# After sweep 8 energy=-1.4127809449581252  maxlinkdim=2 maxerr=9.99E-16 time=0.001
# Fidelity = 0.9999999999999174
# GS energy = -1.4127809449581252
# Current value: g = -0.29292929292929293
# Degeneracy = 2
# After sweep 1 energy=-1.412343134384022  maxlinkdim=2 maxerr=8.38E-16 time=0.002
# After sweep 2 energy=-1.4123431343840223  maxlinkdim=2 maxerr=8.88E-16 time=0.001
# After sweep 3 energy=-1.412343134384022  maxlinkdim=2 maxerr=8.88E-16 time=0.001
# After sweep 4 energy=-1.412343134384023  maxlinkdim=2 maxerr=5.58E-16 time=0.001
# After sweep 5 energy=-1.4123431343840231  maxlinkdim=2 maxerr=7.77E-16 time=0.001
# After sweep 6 energy=-1.4123431343840227  maxlinkdim=2 maxerr=8.84E-16 time=0.001
# After sweep 7 energy=-1.412343134384023  maxlinkdim=2 maxerr=8.90E-16 time=0.006
# After sweep 8 energy=-1.412343134384023  maxlinkdim=2 maxerr=9.60E-16 time=0.002
# Fidelity = 0.9999999999999976
# GS energy = -1.412343134384023
# Current value: g = -0.2727272727272727
# Degeneracy = 2
# After sweep 1 energy=-1.411981039543636  maxlinkdim=2 maxerr=8.08E-16 time=0.006
# After sweep 2 energy=-1.411981039543637  maxlinkdim=2 maxerr=8.88E-16 time=0.001
# After sweep 3 energy=-1.411981039543637  maxlinkdim=2 maxerr=8.27E-16 time=0.001
# After sweep 4 energy=-1.411981039543637  maxlinkdim=2 maxerr=5.55E-16 time=0.001
# After sweep 5 energy=-1.4119810395436374  maxlinkdim=2 maxerr=9.99E-16 time=0.001
# After sweep 6 energy=-1.4119810395436372  maxlinkdim=2 maxerr=7.97E-16 time=0.001
# After sweep 7 energy=-1.4119810395436385  maxlinkdim=2 maxerr=1.00E-15 time=0.001
# After sweep 8 energy=-1.411981039543637  maxlinkdim=2 maxerr=4.48E-16 time=0.001
# Fidelity = 0.9999999999999847
# GS energy = -1.411981039543637
# Current value: g = -0.25252525252525254
# Degeneracy = 2
# After sweep 1 energy=-1.411706757142523  maxlinkdim=2 maxerr=6.48E-16 time=0.002
# After sweep 2 energy=-1.4117067571425215  maxlinkdim=2 maxerr=7.78E-16 time=0.001
# After sweep 3 energy=-1.411706757142522  maxlinkdim=2 maxerr=8.90E-16 time=0.001
# After sweep 4 energy=-1.4117067571425226  maxlinkdim=2 maxerr=8.88E-16 time=0.001
# After sweep 5 energy=-1.4117067571425221  maxlinkdim=2 maxerr=7.77E-16 time=0.001
# After sweep 6 energy=-1.4117067571425228  maxlinkdim=2 maxerr=7.77E-16 time=0.001
# After sweep 7 energy=-1.4117067571425235  maxlinkdim=2 maxerr=9.99E-16 time=0.001
# After sweep 8 energy=-1.4117067571425235  maxlinkdim=2 maxerr=7.72E-16 time=0.001
# Fidelity = 0.9999999999999793
# GS energy = -1.4117067571425235
# Current value: g = -0.23232323232323232
# Degeneracy = 2
# After sweep 1 energy=-1.4115379180613747  maxlinkdim=2 maxerr=6.71E-16 time=0.002
# After sweep 2 energy=-1.4115379180613759  maxlinkdim=2 maxerr=4.81E-16 time=0.002
# After sweep 3 energy=-1.4115379180613752  maxlinkdim=2 maxerr=5.55E-16 time=0.001
# After sweep 4 energy=-1.4115379180613754  maxlinkdim=2 maxerr=7.77E-16 time=0.001
# After sweep 5 energy=-1.4115379180613754  maxlinkdim=2 maxerr=9.99E-16 time=0.001
# After sweep 6 energy=-1.4115379180613759  maxlinkdim=2 maxerr=5.38E-16 time=0.001
# After sweep 7 energy=-1.4115379180613752  maxlinkdim=2 maxerr=6.66E-16 time=0.001
# After sweep 8 energy=-1.4115379180613759  maxlinkdim=2 maxerr=9.44E-16 time=0.001
# Fidelity = 0.9999999999999973
# GS energy = -1.4115379180613759
# Current value: g = -0.21212121212121213
# Degeneracy = 2
# After sweep 1 energy=-1.4114921532681217  maxlinkdim=2 maxerr=8.88E-16 time=0.002
# After sweep 2 energy=-1.4114921532681204  maxlinkdim=2 maxerr=8.88E-16 time=0.001
# After sweep 3 energy=-1.4114921532681195  maxlinkdim=2 maxerr=8.89E-16 time=0.001
# After sweep 4 energy=-1.4114921532681213  maxlinkdim=2 maxerr=9.99E-16 time=0.001
# After sweep 5 energy=-1.411492153268121  maxlinkdim=2 maxerr=6.04E-16 time=0.001
# After sweep 6 energy=-1.4114921532681208  maxlinkdim=2 maxerr=5.75E-16 time=0.006
# After sweep 7 energy=-1.4114921532681206  maxlinkdim=2 maxerr=8.88E-16 time=0.001
# After sweep 8 energy=-1.4114921532681204  maxlinkdim=2 maxerr=1.00E-15 time=0.001
# Fidelity = 1.0
# GS energy = -1.4114921532681204
# Current value: g = -0.1919191919191919
# Degeneracy = 2
# After sweep 1 energy=-1.411579777960169  maxlinkdim=2 maxerr=5.55E-16 time=0.006
# After sweep 2 energy=-1.4115797779601684  maxlinkdim=2 maxerr=5.72E-16 time=0.001
# After sweep 3 energy=-1.4115797779601686  maxlinkdim=2 maxerr=8.88E-16 time=0.001
# After sweep 4 energy=-1.4115797779601686  maxlinkdim=2 maxerr=9.17E-16 time=0.001
# After sweep 5 energy=-1.4115797779601678  maxlinkdim=2 maxerr=1.00E-15 time=0.001
# After sweep 6 energy=-1.41157977796017  maxlinkdim=2 maxerr=6.77E-16 time=0.001
# After sweep 7 energy=-1.411579777960168  maxlinkdim=2 maxerr=8.31E-16 time=0.001
# After sweep 8 energy=-1.4115797779601684  maxlinkdim=2 maxerr=9.06E-16 time=0.001
# Fidelity = 0.9999999999999956
# GS energy = -1.4115797779601684
# Current value: g = -0.1717171717171717
# Degeneracy = 2
# After sweep 1 energy=-1.4117931964300134  maxlinkdim=2 maxerr=8.88E-16 time=0.001
# After sweep 2 energy=-1.411793196430014  maxlinkdim=2 maxerr=6.04E-16 time=0.001
# After sweep 3 energy=-1.4117931964300143  maxlinkdim=2 maxerr=8.88E-16 time=0.001
# After sweep 4 energy=-1.4117931964300139  maxlinkdim=2 maxerr=1.00E-15 time=0.001
# After sweep 5 energy=-1.4117931964300137  maxlinkdim=2 maxerr=7.92E-16 time=0.001
# After sweep 6 energy=-1.4117931964300148  maxlinkdim=2 maxerr=8.91E-16 time=0.001
# After sweep 7 energy=-1.4117931964300143  maxlinkdim=2 maxerr=9.33E-16 time=0.001
# After sweep 8 energy=-1.4117931964300137  maxlinkdim=2 maxerr=7.77E-16 time=0.001
# Fidelity = 1.0
# GS energy = -1.4117931964300137
# Current value: g = -0.15151515151515152
# Degeneracy = 2
# After sweep 1 energy=-1.4120888207184306  maxlinkdim=2 maxerr=9.99E-16 time=0.001
# After sweep 2 energy=-1.4120888207184303  maxlinkdim=2 maxerr=9.12E-16 time=0.001
# After sweep 3 energy=-1.4120888207184294  maxlinkdim=2 maxerr=9.99E-16 time=0.001
# After sweep 4 energy=-1.4120888207184297  maxlinkdim=2 maxerr=8.93E-16 time=0.001
# After sweep 5 energy=-1.4120888207184312  maxlinkdim=2 maxerr=7.82E-16 time=0.001
# After sweep 6 energy=-1.4120888207184306  maxlinkdim=2 maxerr=9.50E-16 time=0.001
# After sweep 7 energy=-1.4120888207184312  maxlinkdim=2 maxerr=1.11E-15 time=0.001
# After sweep 8 energy=-1.4120888207184308  maxlinkdim=2 maxerr=7.83E-16 time=0.001
# Fidelity = 1.0000000000000009
# GS energy = -1.4120888207184308
# Current value: g = -0.13131313131313133
# Degeneracy = 2
# After sweep 1 energy=-1.4123465916976083  maxlinkdim=2 maxerr=1.11E-15 time=0.002
# After sweep 2 energy=-1.4123465916976092  maxlinkdim=2 maxerr=9.54E-16 time=0.001
# After sweep 3 energy=-1.4123465916976081  maxlinkdim=2 maxerr=4.63E-16 time=0.001
# After sweep 4 energy=-1.412346591697607  maxlinkdim=2 maxerr=3.26E-16 time=0.001
# After sweep 5 energy=-1.4123465916976095  maxlinkdim=2 maxerr=9.99E-16 time=0.001
# After sweep 6 energy=-1.4123465916976097  maxlinkdim=2 maxerr=8.88E-16 time=0.001
# After sweep 7 energy=-1.4123465916976095  maxlinkdim=2 maxerr=3.88E-16 time=0.001
# After sweep 8 energy=-1.412346591697609  maxlinkdim=2 maxerr=9.99E-16 time=0.001
# Fidelity = 0.9999999999999996
# GS energy = -1.412346591697609
# Current value: g = -0.1111111111111111
# Degeneracy = 2
# After sweep 1 energy=-1.4122375782709724  maxlinkdim=2 maxerr=7.77E-16 time=0.002
# After sweep 2 energy=-1.4122375782709726  maxlinkdim=2 maxerr=9.99E-16 time=0.001
# After sweep 3 energy=-1.4122375782709724  maxlinkdim=2 maxerr=8.88E-16 time=0.001
# After sweep 4 energy=-1.4122375782709722  maxlinkdim=2 maxerr=9.99E-16 time=0.001
# After sweep 5 energy=-1.4122375782709726  maxlinkdim=2 maxerr=8.93E-16 time=0.001
# After sweep 6 energy=-1.4122375782709728  maxlinkdim=2 maxerr=9.02E-16 time=0.001
# After sweep 7 energy=-1.4122375782709733  maxlinkdim=2 maxerr=7.80E-16 time=0.001
# After sweep 8 energy=-1.4122375782709724  maxlinkdim=2 maxerr=7.82E-16 time=0.001
# Fidelity = 1.0000000000000004
# GS energy = -1.4122375782709724
# Current value: g = -0.09090909090909091
# Degeneracy = 2
# After sweep 1 energy=-1.4106332050842267  maxlinkdim=2 maxerr=7.84E-16 time=0.002
# After sweep 2 energy=-1.410633205084225  maxlinkdim=2 maxerr=4.20E-16 time=0.001
# After sweep 3 energy=-1.4106332050842245  maxlinkdim=2 maxerr=1.01E-15 time=0.001
# After sweep 4 energy=-1.4106332050842256  maxlinkdim=2 maxerr=8.94E-16 time=0.001
# After sweep 5 energy=-1.4106332050842252  maxlinkdim=2 maxerr=3.51E-16 time=0.001
# After sweep 6 energy=-1.4106332050842245  maxlinkdim=2 maxerr=7.77E-16 time=0.001
# After sweep 7 energy=-1.4106332050842245  maxlinkdim=2 maxerr=3.35E-16 time=0.001
# After sweep 8 energy=-1.410633205084225  maxlinkdim=2 maxerr=8.02E-16 time=0.001
# Fidelity = 1.0000000000000004
# GS energy = -1.410633205084225
# Current value: g = -0.0707070707070707
# Degeneracy = 2
# After sweep 1 energy=-1.4041500623144674  maxlinkdim=2 maxerr=8.88E-16 time=0.002
# After sweep 2 energy=-1.404150062314467  maxlinkdim=2 maxerr=3.45E-16 time=0.001
# After sweep 3 energy=-1.4041500623144674  maxlinkdim=2 maxerr=9.99E-16 time=0.001
# After sweep 4 energy=-1.4041500623144676  maxlinkdim=2 maxerr=3.88E-16 time=0.001
# After sweep 5 energy=-1.404150062314467  maxlinkdim=2 maxerr=3.27E-16 time=0.001
# After sweep 6 energy=-1.404150062314468  maxlinkdim=2 maxerr=3.78E-16 time=0.006
# After sweep 7 energy=-1.4041500623144672  maxlinkdim=2 maxerr=3.65E-16 time=0.001
# After sweep 8 energy=-1.404150062314468  maxlinkdim=2 maxerr=1.12E-15 time=0.001
# Fidelity = 1.0000000000000004
# GS energy = -1.404150062314468
# Current value: g = -0.050505050505050504
# Degeneracy = 2
# After sweep 1 energy=-1.3962656061628835  maxlinkdim=2 maxerr=8.89E-16 time=0.001
# After sweep 2 energy=-1.3962656061628838  maxlinkdim=2 maxerr=9.99E-16 time=0.001
# After sweep 3 energy=-1.396265606162884  maxlinkdim=2 maxerr=1.01E-15 time=0.001
# After sweep 4 energy=-1.3962656061628844  maxlinkdim=2 maxerr=4.04E-16 time=0.001
# After sweep 5 energy=-1.3962656061628846  maxlinkdim=2 maxerr=1.01E-15 time=0.005
# After sweep 6 energy=-1.3962656061628842  maxlinkdim=2 maxerr=7.77E-16 time=0.001
# After sweep 7 energy=-1.3962656061628849  maxlinkdim=2 maxerr=1.13E-15 time=0.001
# After sweep 8 energy=-1.3962656061628835  maxlinkdim=2 maxerr=1.01E-15 time=0.001
# Fidelity = 1.0000000000000009
# GS energy = -1.3962656061628835
# Current value: g = -0.030303030303030304
# Degeneracy = 2
# After sweep 1 energy=-1.3911517413744583  maxlinkdim=2 maxerr=1.11E-15 time=0.001
# After sweep 2 energy=-1.391151741374458  maxlinkdim=2 maxerr=1.11E-15 time=0.001
# After sweep 3 energy=-1.3911517413744585  maxlinkdim=2 maxerr=9.99E-16 time=0.001
# After sweep 4 energy=-1.3911517413744587  maxlinkdim=2 maxerr=8.88E-16 time=0.001
# After sweep 5 energy=-1.3911517413744587  maxlinkdim=2 maxerr=9.99E-16 time=0.001
# After sweep 6 energy=-1.3911517413744574  maxlinkdim=2 maxerr=9.01E-16 time=0.001
# After sweep 7 energy=-1.3911517413744574  maxlinkdim=2 maxerr=1.01E-15 time=0.001
# After sweep 8 energy=-1.3911517413744567  maxlinkdim=2 maxerr=9.99E-16 time=0.001
# Fidelity = 0.9999999999999996
# ...
# Degeneracy = 10
# After sweep 1 energy=-4.210825487145466  maxlinkdim=2 maxerr=8.88E-16 time=0.001
# After sweep 2 energy=-4.210825487145465  maxlinkdim=2 maxerr=1.00E-15 time=0.001
# After sweep 3 energy=-4.210825487145467  maxlinkdim=2 maxerr=1.00E-15 time=0.001
# After sweep 4 energy=-4.210825487145465  maxlinkdim=2 maxerr=8.90E-16 time=0.001
# After sweep 5 energy=-4.210825487145464  maxlinkdim=2 maxerr=7.77E-16 time=0.001
# After sweep 6 energy=-4.210825487145465  maxlinkdim=2 maxerr=8.61E-16 time=0.001
# After sweep 7 energy=-4.210825487145469  maxlinkdim=2 maxerr=9.49E-16 time=0.001
# After sweep 8 energy=-4.210825487145467  maxlinkdim=2 maxerr=7.33E-16 time=0.005
# Fidelity = 0.9999999999999998
# GS energy = -4.210825487145467
# Current value: g = 0.6161616161616161
# Degeneracy = 10
# After sweep 1 energy=-4.210825487145466  maxlinkdim=2 maxerr=8.88E-16 time=0.001
# After sweep 2 energy=-4.210825487145465  maxlinkdim=2 maxerr=1.00E-15 time=0.005
# After sweep 3 energy=-4.210825487145467  maxlinkdim=2 maxerr=1.00E-15 time=0.001
# After sweep 4 energy=-4.210825487145465  maxlinkdim=2 maxerr=8.90E-16 time=0.001
# After sweep 5 energy=-4.210825487145464  maxlinkdim=2 maxerr=7.77E-16 time=0.001
# After sweep 6 energy=-4.210825487145465  maxlinkdim=2 maxerr=8.61E-16 time=0.001
# After sweep 7 energy=-4.210825487145469  maxlinkdim=2 maxerr=9.49E-16 time=0.001
# After sweep 8 energy=-4.210825487145467  maxlinkdim=2 maxerr=7.33E-16 time=0.001
# Fidelity = 0.9999999999999998
# GS energy = -4.210825487145467
# Current value: g = 0.6363636363636364
# Degeneracy = 10
# After sweep 1 energy=-4.210825487145466  maxlinkdim=2 maxerr=8.88E-16 time=0.001
# After sweep 2 energy=-4.210825487145465  maxlinkdim=2 maxerr=1.00E-15 time=0.001
# After sweep 3 energy=-4.210825487145467  maxlinkdim=2 maxerr=1.00E-15 time=0.001
# After sweep 4 energy=-4.210825487145465  maxlinkdim=2 maxerr=8.90E-16 time=0.001
# After sweep 5 energy=-4.210825487145464  maxlinkdim=2 maxerr=7.77E-16 time=0.001
# After sweep 6 energy=-4.210825487145465  maxlinkdim=2 maxerr=8.61E-16 time=0.001
# After sweep 7 energy=-4.210825487145469  maxlinkdim=2 maxerr=9.49E-16 time=0.001
# After sweep 8 energy=-4.210825487145467  maxlinkdim=2 maxerr=7.33E-16 time=0.001
# Fidelity = 0.9999999999999998
# GS energy = -4.210825487145467
# Current value: g = 0.6565656565656566
# Degeneracy = 10
# After sweep 1 energy=-4.210825487145466  maxlinkdim=2 maxerr=8.88E-16 time=0.001
# After sweep 2 energy=-4.210825487145465  maxlinkdim=2 maxerr=1.00E-15 time=0.001
# After sweep 3 energy=-4.210825487145467  maxlinkdim=2 maxerr=1.00E-15 time=0.001
# After sweep 4 energy=-4.210825487145465  maxlinkdim=2 maxerr=8.90E-16 time=0.001
# After sweep 5 energy=-4.210825487145464  maxlinkdim=2 maxerr=7.77E-16 time=0.001
# After sweep 6 energy=-4.210825487145465  maxlinkdim=2 maxerr=8.61E-16 time=0.001
# After sweep 7 energy=-4.210825487145469  maxlinkdim=2 maxerr=9.49E-16 time=0.001
# After sweep 8 energy=-4.210825487145467  maxlinkdim=2 maxerr=7.33E-16 time=0.001
# Fidelity = 0.9999999999999998
# GS energy = -4.210825487145467
# Current value: g = 0.6767676767676768
# Degeneracy = 10
# After sweep 1 energy=-4.210825487145466  maxlinkdim=2 maxerr=8.88E-16 time=0.001
# After sweep 2 energy=-4.210825487145465  maxlinkdim=2 maxerr=1.00E-15 time=0.001
# After sweep 3 energy=-4.210825487145467  maxlinkdim=2 maxerr=1.00E-15 time=0.001
# After sweep 4 energy=-4.210825487145465  maxlinkdim=2 maxerr=8.90E-16 time=0.001
# After sweep 5 energy=-4.210825487145464  maxlinkdim=2 maxerr=7.77E-16 time=0.001
# After sweep 6 energy=-4.210825487145465  maxlinkdim=2 maxerr=8.61E-16 time=0.001
# After sweep 7 energy=-4.210825487145469  maxlinkdim=2 maxerr=9.49E-16 time=0.001
# After sweep 8 energy=-4.210825487145467  maxlinkdim=2 maxerr=7.33E-16 time=0.001
# Fidelity = 0.9999999999999998
# GS energy = -4.210825487145467
# Current value: g = 0.696969696969697
# Degeneracy = 10
# After sweep 1 energy=-4.210825487145466  maxlinkdim=2 maxerr=8.88E-16 time=0.001
# After sweep 2 energy=-4.210825487145465  maxlinkdim=2 maxerr=1.00E-15 time=0.001
# After sweep 3 energy=-4.210825487145467  maxlinkdim=2 maxerr=1.00E-15 time=0.001
# After sweep 4 energy=-4.210825487145465  maxlinkdim=2 maxerr=8.90E-16 time=0.001
# After sweep 5 energy=-4.210825487145464  maxlinkdim=2 maxerr=7.77E-16 time=0.001
# After sweep 6 energy=-4.210825487145465  maxlinkdim=2 maxerr=8.61E-16 time=0.001
# After sweep 7 energy=-4.210825487145469  maxlinkdim=2 maxerr=9.49E-16 time=0.001
# After sweep 8 energy=-4.210825487145467  maxlinkdim=2 maxerr=7.33E-16 time=0.001
# Fidelity = 0.9999999999999998
# GS energy = -4.210825487145467
# Current value: g = 0.7171717171717171
# Degeneracy = 10
# After sweep 1 energy=-4.210825487145466  maxlinkdim=2 maxerr=8.88E-16 time=0.001
# After sweep 2 energy=-4.210825487145465  maxlinkdim=2 maxerr=1.00E-15 time=0.001
# After sweep 3 energy=-4.210825487145467  maxlinkdim=2 maxerr=1.00E-15 time=0.001
# After sweep 4 energy=-4.210825487145465  maxlinkdim=2 maxerr=8.90E-16 time=0.001
# After sweep 5 energy=-4.210825487145464  maxlinkdim=2 maxerr=7.77E-16 time=0.001
# After sweep 6 energy=-4.210825487145465  maxlinkdim=2 maxerr=8.61E-16 time=0.001
# After sweep 7 energy=-4.210825487145469  maxlinkdim=2 maxerr=9.49E-16 time=0.001
# After sweep 8 energy=-4.210825487145467  maxlinkdim=2 maxerr=7.33E-16 time=0.001
# Fidelity = 0.9999999999999998
# GS energy = -4.210825487145467
# Current value: g = 0.7373737373737373
# Degeneracy = 10
# After sweep 1 energy=-4.210825487145466  maxlinkdim=2 maxerr=8.88E-16 time=0.001
# After sweep 2 energy=-4.210825487145465  maxlinkdim=2 maxerr=1.00E-15 time=0.001
# After sweep 3 energy=-4.210825487145467  maxlinkdim=2 maxerr=1.00E-15 time=0.001
# After sweep 4 energy=-4.210825487145465  maxlinkdim=2 maxerr=8.90E-16 time=0.001
# After sweep 5 energy=-4.210825487145464  maxlinkdim=2 maxerr=7.77E-16 time=0.001
# After sweep 6 energy=-4.210825487145465  maxlinkdim=2 maxerr=8.61E-16 time=0.001
# After sweep 7 energy=-4.210825487145469  maxlinkdim=2 maxerr=9.49E-16 time=0.001
# After sweep 8 energy=-4.210825487145467  maxlinkdim=2 maxerr=7.33E-16 time=0.001
# Fidelity = 0.9999999999999998
# GS energy = -4.210825487145467
# Current value: g = 0.7575757575757576
# Degeneracy = 10
# After sweep 1 energy=-4.210825487145466  maxlinkdim=2 maxerr=8.88E-16 time=0.001
# After sweep 2 energy=-4.210825487145465  maxlinkdim=2 maxerr=1.00E-15 time=0.001
# After sweep 3 energy=-4.210825487145467  maxlinkdim=2 maxerr=1.00E-15 time=0.001
# After sweep 4 energy=-4.210825487145465  maxlinkdim=2 maxerr=8.90E-16 time=0.001
# After sweep 5 energy=-4.210825487145464  maxlinkdim=2 maxerr=7.77E-16 time=0.001
# After sweep 6 energy=-4.210825487145465  maxlinkdim=2 maxerr=8.61E-16 time=0.001
# After sweep 7 energy=-4.210825487145469  maxlinkdim=2 maxerr=9.49E-16 time=0.001
# After sweep 8 energy=-4.210825487145467  maxlinkdim=2 maxerr=7.33E-16 time=0.001
# Fidelity = 0.9999999999999998
# GS energy = -4.210825487145467
# Current value: g = 0.7777777777777778
# Degeneracy = 10
# After sweep 1 energy=-4.210825487145466  maxlinkdim=2 maxerr=8.88E-16 time=0.001
# After sweep 2 energy=-4.210825487145465  maxlinkdim=2 maxerr=1.00E-15 time=0.001
# After sweep 3 energy=-4.210825487145467  maxlinkdim=2 maxerr=1.00E-15 time=0.001
# After sweep 4 energy=-4.210825487145465  maxlinkdim=2 maxerr=8.90E-16 time=0.001
# After sweep 5 energy=-4.210825487145464  maxlinkdim=2 maxerr=7.77E-16 time=0.001
# After sweep 6 energy=-4.210825487145465  maxlinkdim=2 maxerr=8.61E-16 time=0.001
# After sweep 7 energy=-4.210825487145469  maxlinkdim=2 maxerr=9.49E-16 time=0.001
# After sweep 8 energy=-4.210825487145467  maxlinkdim=2 maxerr=7.33E-16 time=0.001
# Fidelity = 0.9999999999999998
# GS energy = -4.210825487145467
# Current value: g = 0.797979797979798
# Degeneracy = 10
# After sweep 1 energy=-4.210825487145466  maxlinkdim=2 maxerr=8.88E-16 time=0.001
# After sweep 2 energy=-4.210825487145465  maxlinkdim=2 maxerr=1.00E-15 time=0.001
# After sweep 3 energy=-4.210825487145467  maxlinkdim=2 maxerr=1.00E-15 time=0.001
# After sweep 4 energy=-4.210825487145465  maxlinkdim=2 maxerr=8.90E-16 time=0.001
# After sweep 5 energy=-4.210825487145464  maxlinkdim=2 maxerr=7.77E-16 time=0.001
# After sweep 6 energy=-4.210825487145465  maxlinkdim=2 maxerr=8.61E-16 time=0.001
# After sweep 7 energy=-4.210825487145469  maxlinkdim=2 maxerr=9.49E-16 time=0.001
# After sweep 8 energy=-4.210825487145467  maxlinkdim=2 maxerr=7.33E-16 time=0.001
# Fidelity = 0.9999999999999998
# GS energy = -4.210825487145467
# Current value: g = 0.8181818181818182
# Degeneracy = 10
# After sweep 1 energy=-4.210825487145466  maxlinkdim=2 maxerr=8.88E-16 time=0.001
# After sweep 2 energy=-4.210825487145465  maxlinkdim=2 maxerr=1.00E-15 time=0.001
# After sweep 3 energy=-4.210825487145467  maxlinkdim=2 maxerr=1.00E-15 time=0.001
# After sweep 4 energy=-4.210825487145465  maxlinkdim=2 maxerr=8.90E-16 time=0.001
# After sweep 5 energy=-4.210825487145464  maxlinkdim=2 maxerr=7.77E-16 time=0.001
# After sweep 6 energy=-4.210825487145465  maxlinkdim=2 maxerr=8.61E-16 time=0.001
# After sweep 7 energy=-4.210825487145469  maxlinkdim=2 maxerr=9.49E-16 time=0.001
# After sweep 8 energy=-4.210825487145467  maxlinkdim=2 maxerr=7.33E-16 time=0.001
# Fidelity = 0.9999999999999998
# GS energy = -4.210825487145467
# Current value: g = 0.8383838383838383
# Degeneracy = 10
# After sweep 1 energy=-4.210825487145466  maxlinkdim=2 maxerr=8.88E-16 time=0.001
# After sweep 2 energy=-4.210825487145465  maxlinkdim=2 maxerr=1.00E-15 time=0.001
# After sweep 3 energy=-4.210825487145467  maxlinkdim=2 maxerr=1.00E-15 time=0.001
# After sweep 4 energy=-4.210825487145465  maxlinkdim=2 maxerr=8.90E-16 time=0.001
# After sweep 5 energy=-4.210825487145464  maxlinkdim=2 maxerr=7.77E-16 time=0.001
# After sweep 6 energy=-4.210825487145465  maxlinkdim=2 maxerr=8.61E-16 time=0.001
# After sweep 7 energy=-4.210825487145469  maxlinkdim=2 maxerr=9.49E-16 time=0.001
# After sweep 8 energy=-4.210825487145467  maxlinkdim=2 maxerr=7.33E-16 time=0.001
# Fidelity = 0.9999999999999998
# GS energy = -4.210825487145467
# Current value: g = 0.8585858585858586
# Degeneracy = 10
# After sweep 1 energy=-4.210825487145466  maxlinkdim=2 maxerr=8.88E-16 time=0.002
# After sweep 2 energy=-4.210825487145465  maxlinkdim=2 maxerr=1.00E-15 time=0.001
# After sweep 3 energy=-4.210825487145467  maxlinkdim=2 maxerr=1.00E-15 time=0.001
# After sweep 4 energy=-4.210825487145465  maxlinkdim=2 maxerr=8.90E-16 time=0.001
# After sweep 5 energy=-4.210825487145464  maxlinkdim=2 maxerr=7.77E-16 time=0.001
# After sweep 6 energy=-4.210825487145465  maxlinkdim=2 maxerr=8.61E-16 time=0.001
# After sweep 7 energy=-4.210825487145469  maxlinkdim=2 maxerr=9.49E-16 time=0.001
# After sweep 8 energy=-4.210825487145467  maxlinkdim=2 maxerr=7.33E-16 time=0.001
# Fidelity = 0.9999999999999998
# GS energy = -4.210825487145467
# Current value: g = 0.8787878787878788
# Degeneracy = 10
# After sweep 1 energy=-4.210825487145466  maxlinkdim=2 maxerr=8.88E-16 time=0.002
# After sweep 2 energy=-4.210825487145465  maxlinkdim=2 maxerr=1.00E-15 time=0.001
# After sweep 3 energy=-4.210825487145467  maxlinkdim=2 maxerr=1.00E-15 time=0.001
# After sweep 4 energy=-4.210825487145465  maxlinkdim=2 maxerr=8.90E-16 time=0.001
# After sweep 5 energy=-4.210825487145464  maxlinkdim=2 maxerr=7.77E-16 time=0.001
# After sweep 6 energy=-4.210825487145465  maxlinkdim=2 maxerr=8.61E-16 time=0.001
# After sweep 7 energy=-4.210825487145469  maxlinkdim=2 maxerr=9.49E-16 time=0.001
# After sweep 8 energy=-4.210825487145467  maxlinkdim=2 maxerr=7.33E-16 time=0.001
# Fidelity = 0.9999999999999998
# GS energy = -4.210825487145467
# Current value: g = 0.898989898989899
# Degeneracy = 10
# After sweep 1 energy=-4.210825487145466  maxlinkdim=2 maxerr=8.88E-16 time=0.001
# After sweep 2 energy=-4.210825487145465  maxlinkdim=2 maxerr=1.00E-15 time=0.001
# After sweep 3 energy=-4.210825487145467  maxlinkdim=2 maxerr=1.00E-15 time=0.001
# After sweep 4 energy=-4.210825487145465  maxlinkdim=2 maxerr=8.90E-16 time=0.001
# After sweep 5 energy=-4.210825487145464  maxlinkdim=2 maxerr=7.77E-16 time=0.001
# After sweep 6 energy=-4.210825487145465  maxlinkdim=2 maxerr=8.61E-16 time=0.001
# After sweep 7 energy=-4.210825487145469  maxlinkdim=2 maxerr=9.49E-16 time=0.001
# After sweep 8 energy=-4.210825487145467  maxlinkdim=2 maxerr=7.33E-16 time=0.001
# Fidelity = 0.9999999999999998
# GS energy = -4.210825487145467
# Current value: g = 0.9191919191919192
# Degeneracy = 10
# After sweep 1 energy=-4.210825487145466  maxlinkdim=2 maxerr=8.88E-16 time=0.001
# After sweep 2 energy=-4.210825487145465  maxlinkdim=2 maxerr=1.00E-15 time=0.001
# After sweep 3 energy=-4.210825487145467  maxlinkdim=2 maxerr=1.00E-15 time=0.001
# After sweep 4 energy=-4.210825487145465  maxlinkdim=2 maxerr=8.90E-16 time=0.001
# After sweep 5 energy=-4.210825487145464  maxlinkdim=2 maxerr=7.77E-16 time=0.001
# After sweep 6 energy=-4.210825487145465  maxlinkdim=2 maxerr=8.61E-16 time=0.001
# After sweep 7 energy=-4.210825487145469  maxlinkdim=2 maxerr=9.49E-16 time=0.001
# After sweep 8 energy=-4.210825487145467  maxlinkdim=2 maxerr=7.33E-16 time=0.001
# Fidelity = 0.9999999999999998
# GS energy = -4.210825487145467
# Current value: g = 0.9393939393939394
# Degeneracy = 10
# After sweep 1 energy=-4.210825487145466  maxlinkdim=2 maxerr=8.88E-16 time=0.001
# After sweep 2 energy=-4.210825487145465  maxlinkdim=2 maxerr=1.00E-15 time=0.001
# After sweep 3 energy=-4.210825487145467  maxlinkdim=2 maxerr=1.00E-15 time=0.001
# After sweep 4 energy=-4.210825487145465  maxlinkdim=2 maxerr=8.90E-16 time=0.001
# After sweep 5 energy=-4.210825487145464  maxlinkdim=2 maxerr=7.77E-16 time=0.001
# After sweep 6 energy=-4.210825487145465  maxlinkdim=2 maxerr=8.61E-16 time=0.001
# After sweep 7 energy=-4.210825487145469  maxlinkdim=2 maxerr=9.49E-16 time=0.001
# After sweep 8 energy=-4.210825487145467  maxlinkdim=2 maxerr=7.33E-16 time=0.001
# Fidelity = 0.9999999999999998
# GS energy = -4.210825487145467
# Current value: g = 0.9595959595959596
# Degeneracy = 10
# After sweep 1 energy=-4.210825487145466  maxlinkdim=2 maxerr=8.88E-16 time=0.005
# After sweep 2 energy=-4.210825487145465  maxlinkdim=2 maxerr=1.00E-15 time=0.001
# After sweep 3 energy=-4.210825487145467  maxlinkdim=2 maxerr=1.00E-15 time=0.001
# After sweep 4 energy=-4.210825487145465  maxlinkdim=2 maxerr=8.90E-16 time=0.001
# After sweep 5 energy=-4.210825487145464  maxlinkdim=2 maxerr=7.77E-16 time=0.001
# After sweep 6 energy=-4.210825487145465  maxlinkdim=2 maxerr=8.61E-16 time=0.001
# After sweep 7 energy=-4.210825487145469  maxlinkdim=2 maxerr=9.49E-16 time=0.001
# After sweep 8 energy=-4.210825487145467  maxlinkdim=2 maxerr=7.33E-16 time=0.001
# Fidelity = 0.9999999999999998
# GS energy = -4.210825487145467
# Current value: g = 0.9797979797979798
# Degeneracy = 10
# After sweep 1 energy=-4.210825487145466  maxlinkdim=2 maxerr=8.88E-16 time=0.002
# After sweep 2 energy=-4.210825487145465  maxlinkdim=2 maxerr=1.00E-15 time=0.001
# After sweep 3 energy=-4.210825487145467  maxlinkdim=2 maxerr=1.00E-15 time=0.001
# After sweep 4 energy=-4.210825487145465  maxlinkdim=2 maxerr=8.90E-16 time=0.001
# After sweep 5 energy=-4.210825487145464  maxlinkdim=2 maxerr=7.77E-16 time=0.001
# After sweep 6 energy=-4.210825487145465  maxlinkdim=2 maxerr=8.61E-16 time=0.001
# After sweep 7 energy=-4.210825487145469  maxlinkdim=2 maxerr=9.49E-16 time=0.001
# After sweep 8 energy=-4.210825487145467  maxlinkdim=2 maxerr=7.33E-16 time=0.001
# Fidelity = 0.9999999999999998
# GS energy = -4.210825487145467
# Current value: g = 1.0
# Degeneracy = 10
# After sweep 1 energy=-4.210825487145466  maxlinkdim=2 maxerr=8.88E-16 time=0.001
# After sweep 2 energy=-4.210825487145465  maxlinkdim=2 maxerr=1.00E-15 time=0.001
# After sweep 3 energy=-4.210825487145467  maxlinkdim=2 maxerr=1.00E-15 time=0.001
# After sweep 4 energy=-4.210825487145465  maxlinkdim=2 maxerr=8.90E-16 time=0.001
# After sweep 5 energy=-4.210825487145464  maxlinkdim=2 maxerr=7.77E-16 time=0.001
# After sweep 6 energy=-4.210825487145465  maxlinkdim=2 maxerr=8.61E-16 time=0.001
# After sweep 7 energy=-4.210825487145469  maxlinkdim=2 maxerr=9.49E-16 time=0.001
# After sweep 8 energy=-4.210825487145467  maxlinkdim=2 maxerr=7.33E-16 time=0.001
# Fidelity = 0.9999999999999998
# GS energy = -4.210825487145467

# %% [markdown]
# Plotting

# %%
#Verify that the state is the GS of the learned H
pl1 = plot(g_vals, delta_E_HL, label="delta E", title="Energy relative to GS g", xlabel="g", ylabel="delta E")
pl2 = plot(g_vals, λ_vals, label="λ_vals", xlabel="g", ylabel="λ")
pl3 = plot(g_vals, Fidelities_HL, label="F", xlabel="g", ylabel="F")

display(pl1)
display(pl2)
display(pl3)

# %%
p = plot(g_vals, HL_O_exp, label="<O>",linewidth=1, xlabel="g");
plot!(p, g_vals, HL_ZZ_exp / (N - 1), label="<ZZ>",linestyle=:dash,linewidth=3);
display(p)

# %%
ind = 10
@show Fidelities_HL[ind]

v = H_params[ind]
bar(1:length(v), v;
    xlabel="Index",
    ylabel="learned H",
    legend=false,
    lw=2,
    ylim=(-1.1, 1.1),
    title="Hamiltonian for g = $(g_vals[ind])"
    )
# Out:
# Fidelities_HL[ind] = 1.250515303801044e-6

# %%
#Analsysis of the learned H
param3_vals = [v[3] for v in H_params]
# param9_vals = [v[9] for v in H_params]

pl1 = plot(g_vals, param3_vals, label="3", xlabel="g", ylabel="strength")
# plot!(pl1, g_vals, param9_vals, label="9", xlabel="g", ylabel="strength")

# %%
ind_g = 2
@show Fidelities_HL[ind_g]
@show H_params[ind_g]
# Out:
# Fidelities_HL[ind_g] = 9.295183132642807e-12
# H_params[ind_g] = [-1.285496398210314e-6, -5.976004669294534e-8, 2.738818293340228e-11, -3.0748758754992822e-12, 7.692495819155947e-12, 4.161927339470216e-14, -0.00020321825187306742, 0.0002579481542216077, -2.8152335152959897e-9, -3.846345526643124e-9, -0.007178275694075441, 3.9186609280169605e-5, -0.003429691040873619, -2.930060516296572e-8, -0.7078565080553755, -5.0128659221633945e-8, -0.00021475463823914252, -1.071100070022791e-5, -0.020127059577040383, 1.210334266845964e-9, -0.005307086993514313, -0.003519101869328119, -1.9671340872802153e-7, -0.01872310459589906, 5.594087014405899e-7, 0.03902952023270965, -2.500813925083685e-7, -0.704665370936919, 1.0672675928397636e-5, -0.0017108447634478342]
# 30-element Vector{Float64}:
#  -1.285496398210314e-6
#  -5.976004669294534e-8
#   2.738818293340228e-11
#  -3.0748758754992822e-12
#   7.692495819155947e-12
#   4.161927339470216e-14
#  -0.00020321825187306742
#   0.0002579481542216077
#  -2.8152335152959897e-9
#  -3.846345526643124e-9
#   ⋮
#  -0.003519101869328119
#  -1.9671340872802153e-7
#  -0.01872310459589906
#   5.594087014405899e-7
#   0.03902952023270965
#  -2.500813925083685e-7
#  -0.704665370936919
#   1.0672675928397636e-5
#  -0.0017108447634478342
